# %%
import random
import sys
from functions import*
from classes import *
from main import *
from variables import *
sys.path.append("2-Data_Analysis\\1-Numpy\\practica\\entregable_hlf\\functions.py")
sys.path.append("2-Data_Analysis\\1-Numpy\\practica\\entregable_hlf\\main.py")
#sys.path.append("2-Data_Analysis\\1-Numpy\\practica\\entregable_hlf\\variables.py")
fila = random.randint(0, len(tablero_CPU) - 1)
columna = random.randint(0, len(tablero_CPU[0]) - 1)
casilla = (fila, columna)
disparar(casilla, tablero_CPU)
if tablero_CPU[fila][columna] == " ":
    
    print("Agua")

elif tablero_CPU[fila][columna] == "O":

    tablero_CPU[fila][columna] == "X" 

for fila in tablero_CPU:
    print(" ".join(fila))
    break
# Out:
# ['c:\\Users\\19211\\OneDrive\\Escritorio\\Python for Finance\\Python Tutorials\\2304_dsft_thebridge\\2-Data_Analysis\\1-Numpy\\practica\\entregable_hlf', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\python310.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\Users\\19211\\AppData\\Local\\Microsoft\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0', '', 'C:\\Users\\19211\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages', 'C:\\Users\\19211\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\win32', 'C:\\Users\\19211\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_
# ...
